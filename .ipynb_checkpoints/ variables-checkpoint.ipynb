# %%
a=10
b=20
c=a+b
print(c)
# Out:
# 30

# %% [markdown]
# **define python**

# %%
Python is an interpreted, object-oriented, high-level programming language with dynamic semantics. Its high-level built in data structures

# %%
n1=100

# %%
n2=200

# %%
n1+n2
# Out:
# 300

# %% [markdown]
# **Name error**
# - You did not defined/intialized/executed
# - but you are trying to use that

# %%
name='sri'
print(name)
# Out:
# sri

# %%
name="abcd"
print(name)
# Out:
# abcd

# %%
print(name)  #name  'name' not defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(name)
#
# NameError: name 'name' is not defined

# %%
a=10
b=40
a+b+c  #name 'c'not defined  10+20+c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 a=10
#       2 b=40
# ----> 3 a+b+c
#
# NameError: name 'c' is not defined

# %%
NUMBER=100
NUMBER
# Out:
# 100

# %%
number=200
number
# Out:
# 200

# %%
NUMBER,number
# Out:
# (100, 200)

# %%
NUMber=500
NUMber
# Out:
# 500

# %%
number123=700
number123
# Out:
# 700

# %%
123number
123number
# Out:
#   Cell In[16], line 1
#     123number
#       ^
# SyntaxError: invalid decimal literal

# %%
num@ber=100
num@ber   # special characters are not allowed
# Out:
#   Cell In[17], line 1
#     num@ber=100
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
num_ber=100
num_ber
# Out:
# 100

# %%
num@ber=100  #F
$number=300  #F
num_ber=400   #W
areaofcircle=100 #W
area_of_circle=200  #W
area of circle=700  #F

# %%
_=600
_
# Out:
# 600

# %%
if=100
if
# Out:
#   Cell In[24], line 1
#     if=100
#       ^
# SyntaxError: invalid syntax

# %%
if
else
for
while         #  these are key words
True 
False
in

# %%
sum=500
sum
# Out:
# 500

# %%
sum 
max
min      #   these are maths family
len

# %% [markdown]
# - in python some inbuilt functions
# - we will learn functions in upcoming classes
# - function means always ()
#
# - print()
# - type()
# - sum()
# - max()
# - min()
# - len()

# %%
l=[1,2,3,4]

# %%
print(l)
# Out:
# [1, 2, 3, 4]

# %%
type(l)
# Out:
# list

# %%
max(l)
# Out:
# 4

# %%
min(l)
# Out:
# 1

# %%
len(l)
# Out:
# 4

# %%
sum(l)
# Out:
# 10

# %% [markdown]
# - Variables are case sensitive
#
# - Variables does not include spl characters
#
# - Number as prefix not allowed
#
# - Variables can have underscore
#
# - Only underscore also possible
#
# - Variables can be captial and small letters
#
# - reserved or keywords can not be a variable
#
# - inbuilt functions cannot use as variable

# %%
a=100
b=500
c=600
average=(a+b+c)/3
average
# Out:
# 400.0

# %%
pi=3.14
r=100
area_of_circle=pi*r*r
area_of_circle
# Out:
# 31400.0

# %%
bill_amount=200
tip_amount=100
total_bill=bill_amount+tip_amount
total_bill
# Out:
# 300

# %%
weight_in_kgs=500
weight_in_pounds=500*2.2
weight_in_pounds
# Out:
# 1100.0

# %%
dollars=80
indian_currency=80*dollars
indian_currency
# Out:
# 6400

# %%
base=100
height=200
area_of_triangle=1/2*base*height
area_of_triangle
# Out:
# 10000.0

# %%
passbook=230
atm_card_price=500
total_price=passbook+atm_card_price
total_price
# Out:
# 730

# %%
# find the value of length ?
width=2.34
height=20
length=width*height
length
# Out:
# 46.8

# %%
import random

# %%
random.seed(42)
